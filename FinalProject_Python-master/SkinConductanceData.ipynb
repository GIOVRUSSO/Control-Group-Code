# %%
#!/bin/python

import dropbox
import datetime
import schedule
import numpy
import string
import requests

from threading import Timer
import time
import sys

import csv

import math
import random
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation
import os

import matplotlib.dates as mdate

from matplotlib.ticker import MultipleLocator
from matplotlib.ticker import FormatStrFormatter

import pytz

# %%
class SC_Getting:
    
    def __init__():
        dbx = dropbox.Dropbox('lY_d3DAmzgAAAAAAAAAAtgRd7PtJ0xG4weBs1T_9Jp9pCxBjXccJlPYM7vYFC5RF')
        delta = datetime.timedelta(minutes=1)

    def E4(x, y):
        # Dropbox access token    
        dbx = dropbox.Dropbox('lY_d3DAmzgAAAAAAAAAAdn7IAKZUPyYJXhaYmllRlCFZwhYgt_m6fNafXq8DcgWK')

        # current time
        timestamp = datetime.datetime.now()
        # time gap
        delta = datetime.timedelta(minutes = 1)
        # time where the IBI file has been bulit
        filetime = timestamp - delta

        # Re-formatting: datetime->String
        Str_filetime = filetime.strftime('%Y-%m-%d-%H-%M')

        # For testing only 
        # Str_filetime = '2019-06-22-22-25'

        
        # TODO insert
        
        # Set parameters for downloading the file 
        # Saving path
        download_path = 'C:\\FINAL_PROJECT\\EDA_Files\\EDAData'+Str_filetime +'.txt'
        # File location in dropbox    
        path = '/EDA/EDAData'+Str_filetime+'.txt'
        
        # to aviod network delay
        
        #time.sleep(10)
        max = 10
        start = time.time()
        while True:
            ### This will be updated every loop
            remaining = max + start - time.time()
            print "%s seconds remaining" % int(remaining)

            ### Countdown finished, ending loop
            if remaining <= 0:
                break
        
        # try download
        try:
            dbx.files_download_to_file(download_path,path,None)

        except:
                print('Data'+Str_filetime+'.txt current is not exsit'+ 'or check the directory of download_path is exsit')
                pass
        else:
            print("Successful Downloading /Apps/E4Link" + path + " from Dropbox, overwriting " + download_path + "...")

            # A file downloaded, reformat the file
            resval = numpy.loadtxt(download_path)

            with open(download_path, 'r') as f:
                sum = 0
                count = 0
                lines = f.readlines()  # read the content
                for line in lines:
                    for value in line.split():
                        value = value.strip(string.whitespace)
                        sum += float(value)
                        count += 1
                
                f.close()
                
            aveEDA = sum / count
            d005_EDA = int(aveEDA/0.05)
 
            x.append(Str_filetime)
            y.append(aveEDA)
                
            fig = SC_Getting.draw(x, y)

            with open('eda_data.csv', 'a', newline='') as f:
                headers = ['time', 'aveEDA','d005_EDA']
                csv_write = csv.writer(f)
                
                if not os.path.getsize("eda_data.csv"):     
                    # print('no headers')
                    csv_write.writerow(headers) # file doesn't exist yet, write a header
                
                csv_write.writerow([Str_filetime,aveEDA,d005_EDA])
                f.close()

    def bodyE4():
        x = []
        y = []
        #plt.ion()
        #plt.figure(1)
        schedule.every(1).minutes.do(SC_Getting.E4, x, y)
        while True:
            schedule.run_pending()

    def draw(x, y):
        plt.clf()
        plt.plot(x, y, '-r')
        plt.tick_params(axis='x', rotation=90)
        plt.title('eda verus time')
        plt.xlabel('time')
        plt.ylabel('eda')
        plt.pause(0.01)  # pause a bit so that plots are updated



if __name__ == "__main__":
    schedule.clear()
    
    # TODO insert
    EDApath = 'C:\\FINAL_PROJECT\\EDA_Files' #location where you want to save your files
    EDAfolder = os.path.exists(EDApath)
     
    if not EDAfolder:
        os.makedirs(EDApath)
        print("folder created") 

    SC_Getting.bodyE4()
    print ('here')
# Out:
# folder created
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-16-59.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-16-59.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-00.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-00.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-01.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-01.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-02.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-02.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-03.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-03.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-04.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-04.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-05.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-05.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-06.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-06.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-07.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-07.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-08.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-08.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-09.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-09.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-10.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-10.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-11.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-11.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-12.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-12.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-13.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-13.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-14.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-14.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-15.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-15.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-16.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-16.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-17.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-17.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-18.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-18.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-19.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-19.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-20.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-20.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-21.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-21.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-22.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-22.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-23.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-23.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-24.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-24.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-25.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-25.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-26.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-26.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-27.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-27.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-28.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-28.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-29.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-29.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-30.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-30.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-31.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-31.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-33.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-33.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-34.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-34.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-35.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-35.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-36.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-36.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-37.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-37.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-38.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-38.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-39.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-39.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-40.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-40.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-41.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-41.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-42.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-42.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-43.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-43.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-44.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-44.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-45.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-45.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-46.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-46.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-47.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-47.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-48.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-48.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-49.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-49.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-50.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-50.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-51.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-51.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-52.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-52.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-53.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-53.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-54.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-54.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-55.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-55.txt...
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-56.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-56.txt...
# Data2019-08-30-17-57.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-17-58.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/EDA/EDAData2019-08-30-17-59.txt from Dropbox, overwriting C:\FINAL_PROJECT\EDA_Files\EDAData2019-08-30-17-59.txt...
# Data2019-08-30-18-00.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-01.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-02.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-03.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-04.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-05.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-06.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-07.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-08.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-09.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-10.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-11.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-12.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-13.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-14.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-15.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-16.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-17.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-18.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-19.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-20.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-21.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-22.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-23.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-24.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-25.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-26.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-27.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-28.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-29.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-30.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-31.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-32.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-33.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-35.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-36.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-37.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-38.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-39.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-40.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-41.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-42.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-43.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-44.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-45.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-46.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-47.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-48.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-49.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-50.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-51.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-52.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-53.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-54.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-55.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-56.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-57.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-58.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-18-59.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-00.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-01.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-02.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-03.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-04.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-05.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-06.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-07.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-08.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-09.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-10.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-11.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-12.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-13.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-14.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-15.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-16.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-17.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-18.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-19.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-20.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-21.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-22.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-23.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-24.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-25.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-26.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-27.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-28.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-29.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-30.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-31.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-32.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-33.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-34.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-35.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-36.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-37.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-38.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-39.txt current is not exsitor check the directory of download_path is exsit
# Data2019-08-30-19-40.txt current is not exsitor check the directory of download_path is exsit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-108fe6b498a1> in <module>
#     110         print("folder created")
#     111
# --> 112     SC_Getting.bodyE4()
#     113     print ('here')
#
# <ipython-input-3-108fe6b498a1> in bodyE4()
#      86         schedule.every(1).minutes.do(SC_Getting.E4, x, y)
#      87         while True:
# ---> 88             schedule.run_pending()
#      89
#      90     def draw(x, y):
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in run_pending()
#     561     :data:`default scheduler instance <default_scheduler>`.
#     562     """
# --> 563     default_scheduler.run_pending()
#     564
#     565
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in run_pending(self)
#      91         """
#      92         runnable_jobs = (job for job in self.jobs if job.should_run)
# ---> 93         for job in sorted(runnable_jobs):
#      94             self._run_job(job)
#      95
#
# KeyboardInterrupt:
