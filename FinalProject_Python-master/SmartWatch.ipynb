# %%
#!/bin/python

import dropbox
import datetime
import schedule
import numpy
import string
import requests

from threading import Timer
import time
import sys

import csv

import math
import random
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation
import os

import matplotlib.dates as mdate

from matplotlib.ticker import MultipleLocator
from matplotlib.ticker import FormatStrFormatter

import pytz

# %%
class HR_Getting:
    
    def __init__():
        dbx = dropbox.Dropbox('lY_d3DAmzgAAAAAAAAAAtgRd7PtJ0xG4weBs1T_9Jp9pCxBjXccJlPYM7vYFC5RF')
        delta = datetime.timedelta(minutes=1)

    def E4(x, y):
        # Dropbox access token    
        dbx = dropbox.Dropbox('lY_d3DAmzgAAAAAAAAAAdn7IAKZUPyYJXhaYmllRlCFZwhYgt_m6fNafXq8DcgWK')

        # current time
        timestamp = datetime.datetime.now()
        # time gap
        delta = datetime.timedelta(minutes = 1)
        # time where the IBI file has been bulit
        filetime = timestamp - delta

        # Re-formatting: datetime->String
        Str_filetime = filetime.strftime('%Y-%m-%d-%H-%M')

        # For testing only 
        # Str_filetime = '2019-06-22-22-25'

        # Set parameters for downloading the file 
        # Saving path
        download_path = 'C:\\FINAL_PROJECT\\IBI_Files\\IBIData'+Str_filetime +'.txt'
        # File location in dropbox    
        path = '/IBI/IBIData'+Str_filetime+'.txt'

        # try download
        try:
            dbx.files_download_to_file(download_path,path,None)   
        except:
                print('IBIData'+Str_filetime+'.txt current is not exsit'+ 'or check the directory of download_path is exsit')
                pass
        else:
            print("Successful Downloading /Apps/E4Link" + path + " from Dropbox, overwriting " + download_path + "...")

            # A file downloaded, reformat the file
            resval = numpy.loadtxt(download_path)

            with open(download_path, 'r') as f:
                sum = 0
                count = 0
                lines = f.readlines()  # read the content
                for line in lines:
                    for value in line.split():
                        value = value.strip(string.whitespace)
                        sum += float(value)
                        count += 1
                
                f.close()
                
            aveIBI = sum / count
            bpm = int(60 / aveIBI)
            d5_bpm = int(bpm/5)
 
            x.append(Str_filetime)
            y.append(bpm)
                
            fig = HR_Getting.draw(x, y)

            with open('bpm_data.csv', 'a', newline='') as f:
                headers = ['time', 'bpm','d5_bpm' ]
                csv_write = csv.writer(f)
                
                if not os.path.getsize("bpm_data.csv"):     
                    # print('no headers')
                    writer.writerow(headers) # file doesn't exist yet, write a header
                
                csv_write.writerow([Str_filetime, bpm,d5_bpm])
                f.close()
                
            print('The average IBI value(s):', aveIBI, '\n' + 'The heart beat rate(bpm):', bpm, '\n')

    def bodyE4():
        x = []
        y = []
        #plt.ion()
        #plt.figure(1)
        schedule.every(1).minutes.do(HR_Getting.E4, x, y)
        while True:
            schedule.run_pending()

    def draw(x, y):
        plt.clf()
        plt.plot(x, y, '-r')
        plt.tick_params(axis='x', rotation=90)
        plt.title('bpm verus time')
        plt.xlabel('time')
        plt.ylabel('bpm')
        plt.pause(0.01)  # pause a bit so that plots are updated
        #plt.show
        #if 'qt5' in matplotlib.get_backend():
            #display.clear_output(wait=True)
            #display.display(plt.gcf())


if __name__ == "__main__":
    schedule.clear()
    HR_Getting.bodyE4()
    print ('here')
# Out:
# IBIData2019-08-20-18-08.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-09.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-10.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-11.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-11.txt...
# The average IBI value(s): 0.703157
# The heart beat rate(bpm): 85
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-12.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-12.txt...
# The average IBI value(s): 0.8286669483870966
# The heart beat rate(bpm): 72
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-13.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-13.txt...
# The average IBI value(s): 0.8315414348648649
# The heart beat rate(bpm): 72
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-14.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-14.txt...
# The average IBI value(s): 0.8387332476470588
# The heart beat rate(bpm): 71
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-15.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-15.txt...
# The average IBI value(s): 0.846020850857143
# The heart beat rate(bpm): 70
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-16.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-16.txt...
# The average IBI value(s): 0.8281629095999999
# The heart beat rate(bpm): 72
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-17.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-17.txt...
# The average IBI value(s): 0.8312012302777777
# The heart beat rate(bpm): 72
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-18.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-18.txt...
# The average IBI value(s): 0.815529336170213
# The heart beat rate(bpm): 73
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-19.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-19.txt...
# The average IBI value(s): 0.8361231777358497
# The heart beat rate(bpm): 71
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-20.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-20.txt...
# The average IBI value(s): 0.866111048857143
# The heart beat rate(bpm): 69
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-21.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-21.txt...
# The average IBI value(s): 0.8799744489473685
# The heart beat rate(bpm): 68
#
# IBIData2019-08-20-18-23.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-24.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-25.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-26.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-27.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-28.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-29.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-30.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-31.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-18-32.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-33.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-33.txt...
# The average IBI value(s): 0.7239914347619049
# The heart beat rate(bpm): 82
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-34.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-34.txt...
# The average IBI value(s): 0.86625058375
# The heart beat rate(bpm): 69
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-35.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-35.txt...
# The average IBI value(s): 0.8519139944000003
# The heart beat rate(bpm): 70
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-36.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-36.txt...
# The average IBI value(s): 0.7873623905555556
# The heart beat rate(bpm): 76
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-37.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-37.txt...
# The average IBI value(s): 0.820350025
# The heart beat rate(bpm): 73
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-38.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-38.txt...
# The average IBI value(s): 0.8362125206060607
# The heart beat rate(bpm): 71
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-39.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-39.txt...
# The average IBI value(s): 0.8089312442307696
# The heart beat rate(bpm): 74
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-40.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-40.txt...
# The average IBI value(s): 0.8094120484999999
# The heart beat rate(bpm): 74
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-41.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-41.txt...
# The average IBI value(s): 0.8795045416666669
# The heart beat rate(bpm): 68
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-42.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-42.txt...
# The average IBI value(s): 0.8495633556521741
# The heart beat rate(bpm): 70
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-43.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-43.txt...
# The average IBI value(s): 0.8059579371929828
# The heart beat rate(bpm): 74
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-44.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-44.txt...
# The average IBI value(s): 0.6817746273684211
# The heart beat rate(bpm): 88
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-45.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-45.txt...
# The average IBI value(s): 0.810453757
# The heart beat rate(bpm): 74
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-46.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-46.txt...
# The average IBI value(s): 0.9154994941071433
# The heart beat rate(bpm): 65
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-47.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-47.txt...
# The average IBI value(s): 0.854949833809524
# The heart beat rate(bpm): 70
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-48.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-48.txt...
# The average IBI value(s): 0.8264267046666668
# The heart beat rate(bpm): 72
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-49.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-49.txt...
# The average IBI value(s): 0.7511504607142857
# The heart beat rate(bpm): 79
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-50.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-50.txt...
# The average IBI value(s): 0.8475090200000002
# The heart beat rate(bpm): 70
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-51.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-51.txt...
# The average IBI value(s): 0.9107074545652176
# The heart beat rate(bpm): 65
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-52.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-52.txt...
# The average IBI value(s): 0.8788280915151517
# The heart beat rate(bpm): 68
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-53.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-53.txt...
# The average IBI value(s): 0.8464826951724136
# The heart beat rate(bpm): 70
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-54.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-54.txt...
# The average IBI value(s): 0.8600271150980395
# The heart beat rate(bpm): 69
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-55.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-55.txt...
# The average IBI value(s): 0.8536849136666668
# The heart beat rate(bpm): 70
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-56.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-56.txt...
# The average IBI value(s): 0.8768090026415098
# The heart beat rate(bpm): 68
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-57.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-57.txt...
# The average IBI value(s): 0.812537188
# The heart beat rate(bpm): 73
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-58.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-58.txt...
# The average IBI value(s): 0.8441358653333334
# The heart beat rate(bpm): 71
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-20-18-59.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-20-18-59.txt...
# The average IBI value(s): 0.8303432374418604
# The heart beat rate(bpm): 72
#
# IBIData2019-08-20-19-34.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-35.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-36.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-37.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-38.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-39.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-40.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-41.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-42.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-43.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-44.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-45.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-46.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-47.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-48.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-49.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-50.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-51.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-52.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-53.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-54.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-55.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-56.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-57.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-19-59.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-00.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-01.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-02.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-03.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-04.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-05.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-06.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-07.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-08.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-09.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-10.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-11.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-12.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-13.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-14.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-15.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-16.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-17.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-18.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-19.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-20.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-21.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-22.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-23.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-24.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-25.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-26.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-27.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-28.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-29.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-30.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-31.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-32.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-33.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-34.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-35.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-36.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-37.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-38.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-39.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-40.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-41.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-42.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-43.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-44.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-45.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-46.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-47.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-48.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-49.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-50.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-51.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-52.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-53.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-54.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-55.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-56.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-57.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-58.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-20-59.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-00.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-01.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-02.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-03.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-04.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-05.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-06.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-07.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-08.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-09.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-10.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-11.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-12.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-13.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-14.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-15.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-16.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-17.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-18.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-19.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-20.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-21.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-22.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-23.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-24.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-25.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-26.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-27.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-28.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-29.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-30.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-31.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-32.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-33.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-34.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-35.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-36.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-37.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-38.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-39.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-40.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-41.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-42.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-43.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-44.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-45.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-20-21-46.txt current is not exsitor check the directory of download_path is exsit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-175d9f5984cc> in <module>
#      93 if __name__ == "__main__":
#      94     schedule.clear()
# ---> 95     HR_Getting.bodyE4()
#      96     print ('here')
#
# <ipython-input-12-175d9f5984cc> in bodyE4()
#      75         schedule.every(1).minutes.do(HR_Getting.E4, x, y)
#      76         while True:
# ---> 77             schedule.run_pending()
#      78
#      79     def draw(x, y):
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in run_pending()
#     561     :data:`default scheduler instance <default_scheduler>`.
#     562     """
# --> 563     default_scheduler.run_pending()
#     564
#     565
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in run_pending(self)
#      91         """
#      92         runnable_jobs = (job for job in self.jobs if job.should_run)
# ---> 93         for job in sorted(runnable_jobs):
#      94             self._run_job(job)
#      95
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in <genexpr>(.0)
#      90         between but only once.
#      91         """
# ---> 92         runnable_jobs = (job for job in self.jobs if job.should_run)
#      93         for job in sorted(runnable_jobs):
#      94             self._run_job(job)
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in should_run(self)
#     455         :return: ``True`` if the job should be run now.
#     456         """
# --> 457         return datetime.datetime.now() >= self.next_run
#     458
#     459     def run(self):
#
# KeyboardInterrupt:
